# %% [markdown]
# # Import Packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

# %%
import torch
from torch import nn, optim
from jcopdl.callback import Callback, set_config

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %% [markdown]
# # Import Data

# %%
df = pd.read_csv("data/daily_min_temp.csv", parse_dates=["Date"], index_col="Date")
df.head()
# Out:
#             Temp
# Date
# 1981-01-01  20.7
# 1981-01-02  17.9
# 1981-01-03  18.8
# 1981-01-04  14.6
# 1981-01-05  15.8

# %%
df = df.resample("W").mean()

# %%
df.Temp.plot(figsize=(15, 5), color="b")
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# # Dataset Splitting

# %%
ts_train, ts_test = train_test_split(df, test_size=0.2, shuffle=False)
ts_train.shape, ts_test.shape
# Out:
# ((418, 1), (105, 1))

# %% [markdown]
# # Dataset & Dataloader

# %%
from torch.utils.data import TensorDataset, DataLoader
from jcopdl.utils.dataloader import TimeSeriesDataset

# %%
bs = 16
seq_len = 6

train_set = TimeSeriesDataset(ts_train, "Temp", seq_len=seq_len)
trainloader = DataLoader(train_set, batch_size=bs)

test_set = TimeSeriesDataset(ts_test, "Temp", seq_len=seq_len)
testloader = DataLoader(test_set, batch_size=bs)
# Out:
# (N, S, F): (69, 6, 1)
# Note: last 3 data excluded
#
# (N, S, F): (17, 6, 1)
# Note: last 2 data excluded

# %% [markdown]
# # Arsitektur dan Config

# %%
from jcopdl.layers import LinearBlock

# %%
class RNN(nn.Module):
    def __init__(self, input_size, output_size, hidden_size, num_layers, dropout):
        super().__init__()
        self.rnn = nn.RNN(input_size, hidden_size, num_layers, dropout=dropout, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)
        
    def forward(self, x, hidden):
        x, hidden = self.rnn(x, hidden)
        x = self.fc(x)
        return x, hidden

# %%
config = set_config({
    "input_size": train_set.n_feature,
    "output_size": 1,
    "hidden_size": 64,
    "num_layers": 2,
    "dropout": 0,
    "seq_len": train_set.n_seq
})

# %% [markdown]
# # Training Preparation (MCOC)

# %%
model = RNN(config.input_size, config.output_size, config.hidden_size, config.num_layers, config.dropout).to(device)
criterion = nn.MSELoss(reduction="mean")
optimizer = optim.AdamW(model.parameters(), lr=0.001)
callback = Callback(model, config, outdir="model/rnn")

# %% [markdown]
# # Training

# %%
from tqdm.auto import tqdm

def loop_fn(mode, dataset, dataloader, model, criterion, optimizer, device):
    if mode == "train":
        model.train()
    elif mode == "test":
        model.eval()
    cost = 0
    for feature, target in tqdm(dataloader, desc=mode.title()):
        feature, target = feature.to(device), target.to(device)
        output, hidden = model(feature, None)
        loss = criterion(output, target)
        
        if mode == "train":
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()
        
        cost += loss.item() * feature.shape[0]
    cost = cost / len(dataset)
    return cost

# %%
while True:
    train_cost = loop_fn("train", train_set, trainloader, model, criterion, optimizer, device)
    with torch.no_grad():
        test_cost = loop_fn("test", test_set, testloader, model, criterion, optimizer, device)
    
    # Logging
    callback.log(train_cost, test_cost)

    # Checkpoint
    callback.save_checkpoint()
        
    # Runtime Plotting
    callback.cost_runtime_plotting()
    
    # Early Stopping
    if callback.early_stopping(model, monitor="test_cost"):
        callback.plot_cost()
        break
# Out:
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch     1
# Train_cost  = 130.6341 | Test_cost  = 122.2731 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch     2
# Train_cost  = 106.7832 | Test_cost  = 101.2129 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch     3
# Train_cost  = 88.0742 | Test_cost  = 84.3406 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch     4
# Train_cost  = 73.2788 | Test_cost  = 71.7834 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch     5
# Train_cost  = 62.5736 | Test_cost  = 63.0312 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch     6
# Train_cost  = 55.0073 | Test_cost  = 56.4894 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch     7
# Train_cost  = 49.1591 | Test_cost  = 51.0800 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch     8
# Train_cost  = 44.2436 | Test_cost  = 46.3798 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch     9
# Train_cost  = 39.9628 | Test_cost  = 42.2297 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    10
# Train_cost  = 36.1920 | Test_cost  = 38.5451 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    11
# Train_cost  = 32.8580 | Test_cost  = 35.2695 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    12
# Train_cost  = 29.9097 | Test_cost  = 32.3611 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    13
# Train_cost  = 27.3079 | Test_cost  = 29.7850 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    14
# Train_cost  = 25.0189 | Test_cost  = 27.5099 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    15
# Train_cost  = 23.0120 | Test_cost  = 25.5065 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    16
# Train_cost  = 21.2586 | Test_cost  = 23.7478 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    17
# Train_cost  = 19.7325 | Test_cost  = 22.2084 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    18
# Train_cost  = 18.4090 | Test_cost  = 20.8652 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    19
# Train_cost  = 17.2657 | Test_cost  = 19.6965 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    20
# Train_cost  = 16.2819 | Test_cost  = 18.6828 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    21
# Train_cost  = 15.4386 | Test_cost  = 17.8060 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    22
# Train_cost  = 14.7187 | Test_cost  = 17.0499 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    23
# Train_cost  = 14.1066 | Test_cost  = 16.3996 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    24
# Train_cost  = 13.5883 | Test_cost  = 15.8418 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    25
# Train_cost  = 13.1510 | Test_cost  = 15.3646 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    26
# Train_cost  = 12.7838 | Test_cost  = 14.9573 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    27
# Train_cost  = 12.4764 | Test_cost  = 14.6103 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    28
# Train_cost  = 12.2201 | Test_cost  = 14.3154 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    29
# Train_cost  = 12.0073 | Test_cost  = 14.0650 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    30
# Train_cost  = 11.8311 | Test_cost  = 13.8528 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    31
# Train_cost  = 11.6857 | Test_cost  = 13.6731 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    32
# Train_cost  = 11.5660 | Test_cost  = 13.5209 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    33
# Train_cost  = 11.4678 | Test_cost  = 13.3922 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    34
# Train_cost  = 11.3873 | Test_cost  = 13.2833 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    35
# Train_cost  = 11.3215 | Test_cost  = 13.1911 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    36
# Train_cost  = 11.2677 | Test_cost  = 13.1129 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    37
# Train_cost  = 11.2238 | Test_cost  = 13.0466 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    38
# Train_cost  = 11.1878 | Test_cost  = 12.9903 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    39
# Train_cost  = 11.1584 | Test_cost  = 12.9423 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    40
# Train_cost  = 11.1342 | Test_cost  = 12.9013 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    41
# Train_cost  = 11.1143 | Test_cost  = 12.8663 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    42
# Train_cost  = 11.0979 | Test_cost  = 12.8362 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    43
# Train_cost  = 11.0842 | Test_cost  = 12.8102 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    44
# Train_cost  = 11.0727 | Test_cost  = 12.7878 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    45
# Train_cost  = 11.0631 | Test_cost  = 12.7683 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    46
# Train_cost  = 11.0548 | Test_cost  = 12.7512 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    47
# Train_cost  = 11.0478 | Test_cost  = 12.7363 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    48
# Train_cost  = 11.0416 | Test_cost  = 12.7231 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    49
# Train_cost  = 11.0362 | Test_cost  = 12.7113 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    50
# Train_cost  = 11.0313 | Test_cost  = 12.7008 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    51
# Train_cost  = 11.0270 | Test_cost  = 12.6913 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    52
# Train_cost  = 11.0230 | Test_cost  = 12.6827 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    53
# Train_cost  = 11.0193 | Test_cost  = 12.6747 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    54
# Train_cost  = 11.0159 | Test_cost  = 12.6673 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    55
# Train_cost  = 11.0126 | Test_cost  = 12.6604 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    56
# Train_cost  = 11.0095 | Test_cost  = 12.6539 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    57
# Train_cost  = 11.0065 | Test_cost  = 12.6476 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    58
# Train_cost  = 11.0035 | Test_cost  = 12.6416 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    59
# Train_cost  = 11.0006 | Test_cost  = 12.6357 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    60
# Train_cost  = 10.9977 | Test_cost  = 12.6299 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    61
# Train_cost  = 10.9948 | Test_cost  = 12.6242 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    62
# Train_cost  = 10.9918 | Test_cost  = 12.6185 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    63
# Train_cost  = 10.9888 | Test_cost  = 12.6128 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    64
# Train_cost  = 10.9857 | Test_cost  = 12.6070 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    65
# Train_cost  = 10.9825 | Test_cost  = 12.6011 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    66
# Train_cost  = 10.9792 | Test_cost  = 12.5949 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    67
# Train_cost  = 10.9755 | Test_cost  = 12.5885 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    68
# Train_cost  = 10.9715 | Test_cost  = 12.5814 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    69
# Train_cost  = 10.9665 | Test_cost  = 12.5731 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    70
# Train_cost  = 10.9588 | Test_cost  = 12.5604 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    71
# Train_cost  = 10.9406 | Test_cost  = 12.5419 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    72
# Train_cost  = 10.9099 | Test_cost  = 12.5743 |
# ==> EarlyStop patience =  1 | Best test_cost: 12.5419
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    73
# Train_cost  = 10.9056 | Test_cost  = 12.5616 |
# ==> EarlyStop patience =  2 | Best test_cost: 12.5419
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    74
# Train_cost  = 10.8812 | Test_cost  = 12.4880 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    75
# Train_cost  = 10.8418 | Test_cost  = 12.4339 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    76
# Train_cost  = 10.8158 | Test_cost  = 12.4022 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    77
# Train_cost  = 10.7895 | Test_cost  = 12.3781 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    78
# Train_cost  = 10.7624 | Test_cost  = 12.3330 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    79
# Train_cost  = 10.7264 | Test_cost  = 12.2800 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    80
# Train_cost  = 10.6877 | Test_cost  = 12.2295 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    81
# Train_cost  = 10.6363 | Test_cost  = 12.1561 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    82
# Train_cost  = 10.5382 | Test_cost  = 12.0972 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    83
# Train_cost  = 10.4404 | Test_cost  = 11.9756 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    84
# Train_cost  = 10.2364 | Test_cost  = 11.5444 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    85
# Train_cost  = 9.7047 | Test_cost  = 11.0173 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    86
# Train_cost  = 9.1041 | Test_cost  = 10.3303 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    87
# Train_cost  = 8.5618 | Test_cost  = 9.9591 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    88
# Train_cost  = 8.3296 | Test_cost  = 9.6433 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    89
# Train_cost  = 8.0439 | Test_cost  = 9.3275 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    90
# Train_cost  = 7.7751 | Test_cost  = 8.9680 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    91
# Train_cost  = 7.4723 | Test_cost  = 8.6662 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    92
# Train_cost  = 7.2265 | Test_cost  = 8.3204 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    93
# Train_cost  = 6.9567 | Test_cost  = 8.0099 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    94
# Train_cost  = 6.7159 | Test_cost  = 7.6734 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    95
# Train_cost  = 6.4707 | Test_cost  = 7.3736 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    96
# Train_cost  = 6.2428 | Test_cost  = 7.0693 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    97
# Train_cost  = 6.0415 | Test_cost  = 6.8084 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    98
# Train_cost  = 5.8535 | Test_cost  = 6.5707 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    99
# Train_cost  = 5.6892 | Test_cost  = 6.3512 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   100
# Train_cost  = 5.5348 | Test_cost  = 6.1542 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   101
# Train_cost  = 5.3917 | Test_cost  = 5.9593 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   102
# Train_cost  = 5.2584 | Test_cost  = 5.7785 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   103
# Train_cost  = 5.1286 | Test_cost  = 5.6020 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   104
# Train_cost  = 5.0076 | Test_cost  = 5.4336 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   105
# Train_cost  = 4.8919 | Test_cost  = 5.2722 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   106
# Train_cost  = 4.7830 | Test_cost  = 5.1156 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   107
# Train_cost  = 4.6816 | Test_cost  = 4.9674 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   108
# Train_cost  = 4.5867 | Test_cost  = 4.8260 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   109
# Train_cost  = 4.5005 | Test_cost  = 4.6941 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   110
# Train_cost  = 4.4213 | Test_cost  = 4.5715 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   111
# Train_cost  = 4.3493 | Test_cost  = 4.4586 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   112
# Train_cost  = 4.2840 | Test_cost  = 4.3559 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   113
# Train_cost  = 4.2243 | Test_cost  = 4.2623 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   114
# Train_cost  = 4.1704 | Test_cost  = 4.1778 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   115
# Train_cost  = 4.1215 | Test_cost  = 4.1015 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   116
# Train_cost  = 4.0771 | Test_cost  = 4.0326 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   117
# Train_cost  = 4.0370 | Test_cost  = 3.9703 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   118
# Train_cost  = 4.0005 | Test_cost  = 3.9136 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   119
# Train_cost  = 3.9676 | Test_cost  = 3.8618 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   120
# Train_cost  = 3.9375 | Test_cost  = 3.8144 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   121
# Train_cost  = 3.9101 | Test_cost  = 3.7706 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   122
# Train_cost  = 3.8849 | Test_cost  = 3.7302 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   123
# Train_cost  = 3.8616 | Test_cost  = 3.6928 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   124
# Train_cost  = 3.8401 | Test_cost  = 3.6582 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   125
# Train_cost  = 3.8199 | Test_cost  = 3.6260 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   126
# Train_cost  = 3.8011 | Test_cost  = 3.5960 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   127
# Train_cost  = 3.7833 | Test_cost  = 3.5681 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   128
# Train_cost  = 3.7665 | Test_cost  = 3.5420 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   129
# Train_cost  = 3.7506 | Test_cost  = 3.5175 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   130
# Train_cost  = 3.7354 | Test_cost  = 3.4944 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   131
# Train_cost  = 3.7209 | Test_cost  = 3.4726 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   132
# Train_cost  = 3.7070 | Test_cost  = 3.4519 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   133
# Train_cost  = 3.6937 | Test_cost  = 3.4324 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   134
# Train_cost  = 3.6807 | Test_cost  = 3.4140 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   135
# Train_cost  = 3.6682 | Test_cost  = 3.3965 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   136
# Train_cost  = 3.6559 | Test_cost  = 3.3800 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   137
# Train_cost  = 3.6439 | Test_cost  = 3.3644 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   138
# Train_cost  = 3.6322 | Test_cost  = 3.3496 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   139
# Train_cost  = 3.6206 | Test_cost  = 3.3356 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   140
# Train_cost  = 3.6091 | Test_cost  = 3.3223 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   141
# Train_cost  = 3.5978 | Test_cost  = 3.3095 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   142
# Train_cost  = 3.5866 | Test_cost  = 3.2973 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   143
# Train_cost  = 3.5756 | Test_cost  = 3.2855 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   144
# Train_cost  = 3.5648 | Test_cost  = 3.2742 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   145
# Train_cost  = 3.5543 | Test_cost  = 3.2634 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   146
# Train_cost  = 3.5439 | Test_cost  = 3.2530 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   147
# Train_cost  = 3.5338 | Test_cost  = 3.2432 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   148
# Train_cost  = 3.5238 | Test_cost  = 3.2340 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   149
# Train_cost  = 3.5141 | Test_cost  = 3.2253 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   150
# Train_cost  = 3.5046 | Test_cost  = 3.2171 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   151
# Train_cost  = 3.4952 | Test_cost  = 3.2094 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   152
# Train_cost  = 3.4861 | Test_cost  = 3.2020 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   153
# Train_cost  = 3.4772 | Test_cost  = 3.1950 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   154
# Train_cost  = 3.4685 | Test_cost  = 3.1882 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   155
# Train_cost  = 3.4600 | Test_cost  = 3.1816 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   156
# Train_cost  = 3.4517 | Test_cost  = 3.1753 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   157
# Train_cost  = 3.4436 | Test_cost  = 3.1692 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   158
# Train_cost  = 3.4356 | Test_cost  = 3.1633 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   159
# Train_cost  = 3.4279 | Test_cost  = 3.1576 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   160
# Train_cost  = 3.4203 | Test_cost  = 3.1522 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   161
# Train_cost  = 3.4129 | Test_cost  = 3.1469 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   162
# Train_cost  = 3.4056 | Test_cost  = 3.1418 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   163
# Train_cost  = 3.3985 | Test_cost  = 3.1369 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   164
# Train_cost  = 3.3916 | Test_cost  = 3.1322 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   165
# Train_cost  = 3.3848 | Test_cost  = 3.1276 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   166
# Train_cost  = 3.3782 | Test_cost  = 3.1232 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   167
# Train_cost  = 3.3717 | Test_cost  = 3.1190 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   168
# Train_cost  = 3.3653 | Test_cost  = 3.1150 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   169
# Train_cost  = 3.3591 | Test_cost  = 3.1111 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   170
# Train_cost  = 3.3530 | Test_cost  = 3.1074 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   171
# Train_cost  = 3.3471 | Test_cost  = 3.1038 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   172
# Train_cost  = 3.3412 | Test_cost  = 3.1004 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   173
# Train_cost  = 3.3355 | Test_cost  = 3.0971 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   174
# Train_cost  = 3.3299 | Test_cost  = 3.0939 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   175
# Train_cost  = 3.3245 | Test_cost  = 3.0909 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   176
# Train_cost  = 3.3191 | Test_cost  = 3.0880 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   177
# Train_cost  = 3.3139 | Test_cost  = 3.0852 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   178
# Train_cost  = 3.3087 | Test_cost  = 3.0826 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   179
# Train_cost  = 3.3037 | Test_cost  = 3.0801 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   180
# Train_cost  = 3.2987 | Test_cost  = 3.0776 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   181
# Train_cost  = 3.2939 | Test_cost  = 3.0753 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   182
# Train_cost  = 3.2892 | Test_cost  = 3.0731 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   183
# Train_cost  = 3.2845 | Test_cost  = 3.0710 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   184
# Train_cost  = 3.2799 | Test_cost  = 3.0690 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   185
# Train_cost  = 3.2754 | Test_cost  = 3.0671 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   186
# Train_cost  = 3.2710 | Test_cost  = 3.0652 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   187
# Train_cost  = 3.2667 | Test_cost  = 3.0635 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   188
# Train_cost  = 3.2625 | Test_cost  = 3.0618 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   189
# Train_cost  = 3.2583 | Test_cost  = 3.0602 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   190
# Train_cost  = 3.2542 | Test_cost  = 3.0587 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   191
# Train_cost  = 3.2502 | Test_cost  = 3.0573 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   192
# Train_cost  = 3.2462 | Test_cost  = 3.0560 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   193
# Train_cost  = 3.2423 | Test_cost  = 3.0547 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   194
# Train_cost  = 3.2385 | Test_cost  = 3.0535 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   195
# Train_cost  = 3.2347 | Test_cost  = 3.0524 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   196
# Train_cost  = 3.2309 | Test_cost  = 3.0513 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   197
# Train_cost  = 3.2273 | Test_cost  = 3.0503 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   198
# Train_cost  = 3.2236 | Test_cost  = 3.0494 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   199
# Train_cost  = 3.2201 | Test_cost  = 3.0485 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   200
# Train_cost  = 3.2165 | Test_cost  = 3.0477 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   201
# Train_cost  = 3.2131 | Test_cost  = 3.0470 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   202
# Train_cost  = 3.2096 | Test_cost  = 3.0463 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   203
# Train_cost  = 3.2062 | Test_cost  = 3.0457 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   204
# Train_cost  = 3.2029 | Test_cost  = 3.0451 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   205
# Train_cost  = 3.1996 | Test_cost  = 3.0446 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   206
# Train_cost  = 3.1963 | Test_cost  = 3.0442 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   207
# Train_cost  = 3.1930 | Test_cost  = 3.0438 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   208
# Train_cost  = 3.1898 | Test_cost  = 3.0434 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   209
# Train_cost  = 3.1866 | Test_cost  = 3.0431 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   210
# Train_cost  = 3.1835 | Test_cost  = 3.0428 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   211
# Train_cost  = 3.1803 | Test_cost  = 3.0426 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   212
# Train_cost  = 3.1772 | Test_cost  = 3.0424 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   213
# Train_cost  = 3.1741 | Test_cost  = 3.0423 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   214
# Train_cost  = 3.1711 | Test_cost  = 3.0422 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   215
# Train_cost  = 3.1681 | Test_cost  = 3.0422 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   216
# Train_cost  = 3.1651 | Test_cost  = 3.0421 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   217
# Train_cost  = 3.1621 | Test_cost  = 3.0421 |
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   218
# Train_cost  = 3.1591 | Test_cost  = 3.0422 |
# ==> EarlyStop patience =  1 | Best test_cost: 3.0421
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   219
# Train_cost  = 3.1562 | Test_cost  = 3.0422 |
# ==> EarlyStop patience =  2 | Best test_cost: 3.0421
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   220
# Train_cost  = 3.1533 | Test_cost  = 3.0423 |
# ==> EarlyStop patience =  3 | Best test_cost: 3.0421
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   221
# Train_cost  = 3.1504 | Test_cost  = 3.0424 |
# ==> EarlyStop patience =  4 | Best test_cost: 3.0421
# Train:   0%|          | 0/5 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   222
# Train_cost  = 3.1475 | Test_cost  = 3.0425 |
# ==> EarlyStop patience =  5 | Best test_cost: 3.0421
# ==> Execute Early Stopping at epoch: 222 | Best test_cost: 3.0421
# ==> Best model is saved at model/rnn

# %% [markdown]
# # Forecast

# %%
from luwiji.rnn import illustration

# %%
illustration.forecast

# %%
from utils import data4pred, pred4pred

# %%
train_forecast_set = TimeSeriesDataset(ts_train, "Temp", 1)
trainforecastloader = DataLoader(train_set)

test_forecast_set = TimeSeriesDataset(ts_test, "Temp", 1)
testforecastloader = DataLoader(test_set)
# Out:
# (N, S, F): (417, 1, 1)
# Note: last 0 data excluded
#
# (N, S, F): (104, 1, 1)
# Note: last 0 data excluded
